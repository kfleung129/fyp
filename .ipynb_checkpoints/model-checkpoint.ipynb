# %%
#environment settings
#!pip install tensorflow matplotlib numpy==1.19.5 yfinance

# %%
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import yfinance as yf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Input
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
import tensorflow as tf

# %%
#common variables
sc = MinMaxScaler(feature_range=(0,1))

# %%
#tf.test.is_gpu_available()
#tf.config.list_physical_devices('GPU')

# %%
#common functions
def load_dataframe(**kwargs):
    stock_name = kwargs["stock_name"]
    start_year = kwargs["start_year"]
    end_year = kwargs["end_year"]
    df = yf.download(stock_name, start=f'{start_year}-01-01', end=f'{end_year}-01-01')
    #df = pd.read_csv(f'./stocks/{name}.csv') # Default load local csv file
    return df
    
def get_X_train(**kwargs):
    df = kwargs['df']
    start_index = kwargs['start_index']
    end_index = kwargs['end_index']
    day_before = kwargs["day_before"]
    X_train = df.iloc[start_index:end_index, 0:1].values
    X_train = sc.fit_transform(X_train)
    X_train = [X_train[i-day_before:i, 0] for i in range(day_before, len(X_train))]
    X_train = np.array(X_train)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    return X_train

def get_y_train(**kwargs):
    df = kwargs['df']
    start_index = kwargs['start_index']
    end_index = kwargs['end_index']
    day_before = kwargs['day_before']
    y_train = df.iloc[start_index:end_index, 1:2].values
    y_train = sc.fit_transform(y_train)[0+day_before:end_index]
    return y_train
    
def get_X_test():
    return 1
def get_y_test():
    return 1

# %%
stock_name = "AAPL"
start_year = 2002
end_year = 2022
start_index = 0
end_index = 4600
day_before = 60

# %%
df = load_dataframe(stock_name="AAPL", start_year=start_year, end_year=end_year)
print("Number of rows and columns:", df.shape)
#df.head(5)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Number of rows and columns: (5036, 6)

# %%
X_train = get_X_train(df=df, start_index=start_index, end_index=end_index, day_before=day_before)
y_train = get_y_train(df=df, start_index=start_index, end_index=end_index, day_before=day_before)
print(X_train.shape)
print(y_train.shape)
# Out:
# (4540, 60, 1)
# (4540, 1)

# %%
#splitin train set & train set
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

sc = MinMaxScaler(feature_range = (0, 1))

# %%
# Feature Scaling
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (740, 60, 1)
# y_train shape: (740,)

# %%
#numpy version require 1.19.5 
#!pip install numpy==1.19.5
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 7s 49ms/step - loss: 0.0188
# Epoch 2/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0041
# Epoch 3/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0023
# Epoch 4/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0032
# Epoch 5/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0024
# Epoch 6/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0020
# Epoch 7/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0022
# Epoch 8/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0023
# Epoch 9/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0022
# Epoch 10/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0020
# Epoch 11/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0020
# Epoch 12/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0022
# Epoch 13/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0022
# Epoch 14/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0018
# Epoch 15/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0021
# Epoch 16/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0019
# Epoch 17/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0019
# Epoch 18/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0019
# Epoch 19/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0027
# Epoch 20/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0029
# Epoch 21/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0015
# Epoch 22/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0016
# Epoch 23/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0013
# Epoch 24/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0013
# Epoch 25/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0018
# Epoch 26/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0013
# Epoch 27/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0018
# Epoch 28/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0016
# Epoch 29/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0017
# Epoch 30/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0013
# Epoch 31/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0017
# Epoch 32/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0016
# Epoch 33/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0019
# Epoch 34/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0015
# Epoch 35/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0013
# Epoch 36/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0013
# Epoch 37/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0016
# Epoch 38/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 39/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0014
# Epoch 40/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0012
# Epoch 41/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0013
# Epoch 42/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0015
# Epoch 43/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0014
# Epoch 44/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 45/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0016
# Epoch 46/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0016
# Epoch 47/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0012
# Epoch 48/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0013
# Epoch 49/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 50/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0011
# Epoch 51/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0011
# Epoch 52/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0015
# Epoch 53/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0014
# Epoch 54/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 55/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 56/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0012
# Epoch 57/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0013
# Epoch 58/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0017
# Epoch 59/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0011
# Epoch 60/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0013
# Epoch 61/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0010
# Epoch 62/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0013
# Epoch 63/100
# 24/24 [==============================] - 1s 49ms/step - loss: 9.1100e-04
# Epoch 64/100
# 24/24 [==============================] - 1s 51ms/step - loss: 9.9347e-04
# Epoch 65/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0015
# Epoch 66/100
# 24/24 [==============================] - 1s 48ms/step - loss: 9.2711e-04
# Epoch 67/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0012
# Epoch 68/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0013
# Epoch 69/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 70/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 71/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 72/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 73/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 74/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 75/100
# 24/24 [==============================] - 1s 49ms/step - loss: 8.4780e-04
# Epoch 76/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 77/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0017
# Epoch 78/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0014
# Epoch 79/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0011
# Epoch 80/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0010
# Epoch 81/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0012
# Epoch 82/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 83/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 84/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 85/100
# 24/24 [==============================] - 1s 48ms/step - loss: 8.9371e-04
# Epoch 86/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0010
# Epoch 87/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0010
# Epoch 88/100
# 24/24 [==============================] - 1s 52ms/step - loss: 7.2284e-04
# Epoch 89/100
# 24/24 [==============================] - 1s 55ms/step - loss: 7.3161e-04
# Epoch 90/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 91/100
# 24/24 [==============================] - 1s 55ms/step - loss: 8.7914e-04
# Epoch 92/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0017
# Epoch 93/100
# 24/24 [==============================] - 1s 49ms/step - loss: 9.7201e-04
# Epoch 94/100
# 24/24 [==============================] - 1s 50ms/step - loss: 8.3325e-04
# Epoch 95/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0011
# Epoch 96/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0011
# Epoch 97/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 98/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0011
# Epoch 99/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0011
# Epoch 100/100
# 24/24 [==============================] - 1s 49ms/step - loss: 8.8640e-04

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 0:1]
dataset_test = df.iloc[end_index:, 0:1]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 519):
    X_test.append(inputs[i-60:i, 0])
#X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# (459, 60, 1)

# %%
X_tmp = get_X_train(df=df, start_index=end_index, end_index=len(df), day_before=60)
X_tmp.shape
# Out:
# (376, 60, 1)

# %%
predicted_stock_price = model.predict(X_tmp)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 12/12 [==============================] - 1s 17ms/step

# %%
# Visualising the results
plt.figure(figsize=(10,6))
plt.plot(df.index.values[end_index:len(df)-60], dataset_test[0:len(dataset_test)-60].values, color = "red", label = f'Real {stock_name} Stock Price')
plt.plot(df.index.values[end_index:len(df)-60], predicted_stock_price, color = "blue", label = f'Predicted {stock_name} Stock Price')
#plt.xticks(np.arange(0,459,100))
plt.title(f'{stock_name} Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(f'{stock_name} Stock Price')
plt.legend()
plt.show()

# %%
### Sentiment Analysis

# %%
predicted_stock_price
# Out:
# array([[ 90.312256],
#        [ 90.937096],
#        [ 91.75943 ],
#        [ 92.67055 ],
#        [ 93.623535],
#        [ 94.43416 ],
#        [ 95.171265],
#        [ 95.7756  ],
#        [ 96.211105],
#        [ 96.44754 ],
#        [ 96.62982 ],
#        [ 96.74672 ],
#        [ 96.78885 ],
#        [ 96.482506],
#        [ 95.85671 ],
#        [ 95.10449 ],
#        [ 94.39128 ],
#        [ 93.85012 ],
#        [ 93.95445 ],
#        [ 95.15216 ],
#        [ 97.44457 ],
#        [100.4178  ],
#        [103.54201 ],
#        [106.47861 ],
#        [108.940865],
#        [110.72997 ],
#        [111.72994 ],
#        [112.197334],
#        [112.41572 ],
#        [112.6318  ],
#        [112.86765 ],
#        [113.16878 ],
#        [113.52586 ],
#        [114.0801  ],
#        [115.343735],
#        [117.21282 ],
#        [119.392914],
#        [121.57745 ],
#        [123.44404 ],
#        [124.89005 ],
#        [126.17586 ],
#        [127.69142 ],
#        [128.9613  ],
#        [129.2993  ],
#        [128.25015 ],
#        [126.131035],
#        [123.67371 ],
#        [121.2377  ],
#        [119.08931 ],
#        [117.5817  ],
#        [116.71791 ],
#        [116.10315 ],
#        [115.50096 ],
#        [114.57514 ],
#        [113.64394 ],
#        [112.97049 ],
#        [112.356255],
#        [111.798485],
#        [111.65387 ],
#        [112.06092 ],
#        [112.8766  ],
#        [114.0386  ],
#        [115.14925 ],
#        [115.95836 ],
#        [116.46435 ],
#        [116.67971 ],
#        [116.73476 ],
#        [116.68721 ],
#        [116.8094  ],
#        [117.485275],
#        [118.55239 ],
#        [119.59177 ],
#        [120.43858 ],
#        [120.97921 ],
#        [121.019394],
#        [120.58092 ],
#        [119.86507 ],
#        [119.043144],
#        [118.14865 ],
#        [117.31403 ],
#        [116.63358 ],
#        [116.02818 ],
#        [115.389496],
#        [114.608864],
#        [113.73079 ],
#        [113.08322 ],
#        [113.05365 ],
#        [113.74413 ],
#        [115.081215],
#        [116.53866 ],
#        [117.767204],
#        [118.7221  ],
#        [119.42075 ],
#        [119.86781 ],
#        [120.11849 ],
#        [120.184006],
#        [120.04554 ],
#        [119.7891  ],
#        [119.43831 ],
#        [118.8762  ],
#        [118.178795],
#        [117.52782 ],
#        [117.07886 ],
#        [117.09077 ],
#        [117.66662 ],
#        [118.762436],
#        [120.117935],
#        [121.43088 ],
#        [122.58998 ],
#        [123.545975],
#        [124.07465 ],
#        [124.20092 ],
#        [124.05445 ],
#        [123.864975],
#        [123.931526],
#        [124.43008 ],
#        [125.31391 ],
#        [126.19901 ],
#        [127.139206],
#        [128.1854  ],
#        [129.2436  ],
#        [130.32419 ],
#        [131.58643 ],
#        [132.88991 ],
#        [133.97385 ],
#        [134.66144 ],
#        [134.70421 ],
#        [134.06316 ],
#        [132.95956 ],
#        [131.89326 ],
#        [131.04556 ],
#        [130.43567 ],
#        [130.04942 ],
#        [129.95503 ],
#        [130.04645 ],
#        [130.16092 ],
#        [130.2475  ],
#        [130.55382 ],
#        [131.30223 ],
#        [132.80252 ],
#        [134.98201 ],
#        [137.45699 ],
#        [139.59183 ],
#        [140.8397  ],
#        [140.9923  ],
#        [140.31866 ],
#        [139.21767 ],
#        [138.07791 ],
#        [137.21043 ],
#        [136.68414 ],
#        [136.48927 ],
#        [136.54712 ],
#        [136.73068 ],
#        [136.86597 ],
#        [136.9287  ],
#        [136.73651 ],
#        [136.15544 ],
#        [135.29274 ],
#        [134.23215 ],
#        [132.91058 ],
#        [131.45847 ],
#        [130.05612 ],
#        [128.76575 ],
#        [127.70196 ],
#        [127.16217 ],
#        [127.062996],
#        [127.070496],
#        [126.92185 ],
#        [126.53352 ],
#        [125.86577 ],
#        [125.12137 ],
#        [124.52448 ],
#        [124.08152 ],
#        [123.79789 ],
#        [123.86063 ],
#        [124.225464],
#        [124.6912  ],
#        [124.938324],
#        [124.84506 ],
#        [124.59725 ],
#        [124.3465  ],
#        [124.013466],
#        [123.59668 ],
#        [123.20497 ],
#        [122.84675 ],
#        [122.598434],
#        [122.594925],
#        [122.87005 ],
#        [123.4822  ],
#        [124.322556],
#        [125.37479 ],
#        [126.57987 ],
#        [127.93924 ],
#        [129.34456 ],
#        [130.76482 ],
#        [132.05173 ],
#        [133.1006  ],
#        [133.82024 ],
#        [134.27756 ],
#        [134.42516 ],
#        [134.32301 ],
#        [134.0318  ],
#        [133.77443 ],
#        [133.70035 ],
#        [133.80861 ],
#        [134.14583 ],
#        [134.44379 ],
#        [134.54736 ],
#        [134.39597 ],
#        [133.94606 ],
#        [133.20934 ],
#        [132.44556 ],
#        [131.79451 ],
#        [131.03812 ],
#        [130.08296 ],
#        [129.04892 ],
#        [128.17921 ],
#        [127.65418 ],
#        [127.4978  ],
#        [127.4622  ],
#        [127.46422 ],
#        [127.60199 ],
#        [127.82228 ],
#        [128.13518 ],
#        [128.46928 ],
#        [128.7269  ],
#        [128.81195 ],
#        [128.68262 ],
#        [128.33583 ],
#        [127.85644 ],
#        [127.31895 ],
#        [126.900276],
#        [126.71848 ],
#        [126.81252 ],
#        [127.1155  ],
#        [127.49374 ],
#        [127.899475],
#        [128.39769 ],
#        [129.00882 ],
#        [129.64905 ],
#        [130.26569 ],
#        [130.78604 ],
#        [131.25497 ],
#        [131.77507 ],
#        [132.39705 ],
#        [133.0313  ],
#        [133.57616 ],
#        [134.04012 ],
#        [134.50258 ],
#        [135.0088  ],
#        [135.60463 ],
#        [136.36823 ],
#        [137.43571 ],
#        [138.6514  ],
#        [139.86371 ],
#        [141.10628 ],
#        [142.23111 ],
#        [143.31671 ],
#        [144.42769 ],
#        [145.48647 ],
#        [146.1632  ],
#        [146.31842 ],
#        [146.12021 ],
#        [145.7986  ],
#        [145.60092 ],
#        [145.66997 ],
#        [146.04324 ],
#        [146.4298  ],
#        [146.63345 ],
#        [146.59386 ],
#        [146.45766 ],
#        [146.32648 ],
#        [146.32518 ],
#        [146.4741  ],
#        [146.70032 ],
#        [146.92317 ],
#        [147.10576 ],
#        [147.21832 ],
#        [147.26625 ],
#        [147.40245 ],
#        [147.66736 ],
#        [148.10506 ],
#        [148.64891 ],
#        [148.9714  ],
#        [149.04117 ],
#        [148.96962 ],
#        [148.9189  ],
#        [148.98703 ],
#        [149.11186 ],
#        [149.18503 ],
#        [149.23119 ],
#        [149.45618 ],
#        [149.93234 ],
#        [150.64323 ],
#        [151.46698 ],
#        [152.31825 ],
#        [153.20013 ],
#        [153.99252 ],
#        [154.58026 ],
#        [154.72018 ],
#        [154.37427 ],
#        [153.59457 ],
#        [152.5551  ],
#        [151.48822 ],
#        [150.34822 ],
#        [149.17293 ],
#        [148.08916 ],
#        [147.31746 ],
#        [146.9068  ],
#        [146.79648 ],
#        [146.77785 ],
#        [146.67987 ],
#        [146.50554 ],
#        [146.2196  ],
#        [145.83432 ],
#        [145.29358 ],
#        [144.62335 ],
#        [144.07642 ],
#        [143.84818 ],
#        [143.87956 ],
#        [144.09283 ],
#        [144.2942  ],
#        [144.40965 ],
#        [144.50697 ],
#        [144.61542 ],
#        [144.90463 ],
#        [145.49054 ],
#        [146.32086 ],
#        [147.28427 ],
#        [148.18146 ],
#        [148.90327 ],
#        [149.40747 ],
#        [149.72424 ],
#        [149.77571 ],
#        [149.65645 ],
#        [149.45845 ],
#        [149.33904 ],
#        [149.42665 ],
#        [149.74268 ],
#        [150.19254 ],
#        [150.60663 ],
#        [150.87712 ],
#        [150.93152 ],
#        [150.76552 ],
#        [150.53815 ],
#        [150.35081 ],
#        [150.2994  ],
#        [150.52957 ],
#        [151.22597 ],
#        [152.5213  ],
#        [154.21648 ],
#        [155.96332 ],
#        [157.41371 ],
#        [158.38954 ],
#        [158.91322 ],
#        [159.4373  ],
#        [159.77109 ],
#        [160.0395  ],
#        [160.33498 ],
#        [160.89844 ],
#        [161.89478 ],
#        [163.34908 ],
#        [165.0606  ],
#        [167.01094 ],
#        [168.7524  ],
#        [170.00246 ],
#        [170.87991 ],
#        [171.11185 ],
#        [170.63211 ],
#        [169.76338 ],
#        [168.89941 ],
#        [168.4088  ],
#        [168.45665 ],
#        [169.09895 ],
#        [170.12369 ],
#        [171.26057 ]], dtype=float32)
